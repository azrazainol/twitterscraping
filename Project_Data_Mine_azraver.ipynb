# %% [markdown]
# <a href="https://colab.research.google.com/github/azrazainol/twitterscraping/blob/main/Project_Data_Mine_azraver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ntscraper

# %%
import pandas as pd
from ntscraper import Nitter

scraper = Nitter()
# Out:
# Testing instances: 100%|██████████| 30/30 [00:46<00:00,  1.55s/it]

# %%
terms = "palestine"

tweets = scraper.get_tweets(terms, mode='term',since ="2023-10-07",number=3000,)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.woodland.cafe
# INFO:root:Current stats for palestine: 14 tweets, 0 threads...
# INFO:root:Current stats for palestine: 28 tweets, 0 threads...
# INFO:root:Current stats for palestine: 41 tweets, 0 threads...
# INFO:root:Current stats for palestine: 57 tweets, 0 threads...
# INFO:root:Current stats for palestine: 69 tweets, 0 threads...
# INFO:root:Current stats for palestine: 83 tweets, 0 threads...
# INFO:root:Current stats for palestine: 96 tweets, 0 threads...
# INFO:root:Current stats for palestine: 106 tweets, 0 threads...
# INFO:root:Current stats for palestine: 118 tweets, 0 threads...
# INFO:root:Current stats for palestine: 133 tweets, 0 threads...
# INFO:root:Current stats for palestine: 146 tweets, 0 threads...
# INFO:root:Current stats for palestine: 156 tweets, 0 threads...
# INFO:root:Current stats for palestine: 163 tweets, 0 threads...
# ...

# %%
final_tweets = []
for tweet in tweets['tweets']:
	data1 = [tweet['link'],tweet['text'],tweet['user']['name'],tweet['user']['username'],
	tweet['date'],tweet['is-retweet'],tweet['stats']['comments'],tweet['stats']['retweets'],
	tweet['stats']['quotes'],tweet['stats']['likes']]
	final_tweets.append(data1)
	print('----Siguiente tweet----')
# Out:
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ----Siguiente tweet----
# ...

# %%
data2 = pd.DataFrame(final_tweets,columns=[
	'link','text','name','username','date','is_rt','n_comment','n_rt','n_quote','n_like'])

# %%
data2
# Out:
#                                                    link  \
# 0     https://twitter.com/aliciavperry/status/173857...
# 1     https://twitter.com/26njd77/status/17390731787...
# 2     https://twitter.com/luckqqqqy/status/173918014...
# 3     https://twitter.com/ksybrainrot/status/1739168...
# 4     https://twitter.com/evermoresivy/status/173903...
# ...                                                 ...
# 2995  https://twitter.com/LarryBoorstein/status/1738...
# 2996  https://twitter.com/BridMcGrath/status/1739220...
# 2997  https://twitter.com/islamidavet/status/1739216...
# 2998  https://twitter.com/drsyedrazaali4/status/1739...
# 2999  https://twitter.com/mikesjw1/status/1739209378...
#
#                                                    text  \
# 0     Cork city sings for Palestine! 🇮🇪🙏🇵🇸  #InvokeG...
# 1     before 2023 ends, quote this tweet with your f...
# 2     Hello Vine,  We do NOT want SECRET NUMBER to a...
# 3     seventeen brought soonyoung instead of hoshi t...
# ...

# %%
data2.to_csv('Tweet_' + str(terms) + '.csv',encoding='utf-8-sig',index=False)
